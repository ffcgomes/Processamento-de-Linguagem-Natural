# %% [markdown]
# #A house web scraper in Python!
# In a few months I’ll have to leave my rented apartment and look for a new one. As painful as this experience can be, especially as a real estate bubble looms in the horizon, I decided to use it as yet another incentive to improve my Python skills! In the end I want to be able to do two things:
# · Scrape all the search results from one of the main real estate websites in Portugal (where I live) and build a database with all the listings found
# · Use the collected listings to perform some EDA, and ultimately try to find undervalued properties
# The website I will be scraping is the real estate portal from Sapo, one of the oldest and most visited websites in Portugal. They have a very large amount of real estate listings for us to scrape. Chances are you are using a different website, but you should be able to adapt the code very easily.
# Before we begin with the code snippets, let me just give you a summary of what I will be doing. I will use the results page from a simple search in Sapo website where I can specify some parameters beforehand (like zone, price filters, number of rooms, etc) to reduce the task time, or simply query the whole list of results in Lisbon.
# We then need to use a command to reach ask a response from the website. The result will be some html code, which we will then use to get the elements we want for our final table. After deciding what to take from each search result property, we need a for loop to open each of the search pages and perform the scraping.
# That sounds pretty easy, where do I start?
# Like most projects, we need to import the modules to be used. I will use Beautiful Soup to take care of the html’s we will be fetching. Always make sure the site you are trying to access allows scraping. You can easily do that if you add “/robots.txt” to the original domain. Inside this file you can see if there are guidelines regarding what is allowed to scrape.

# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Some websites automatically block any kind of scraping, and that’s why I’ll define a header to pass along the get command, which will basically make our queries to the website look like they are coming from an actual browser. When we run the program, I’ll have a sleep command between pages, so we can mimic a “more human” behavior and don’t overload the site with several requests per second. You will get blocked if you scrape too aggressively, so it’s a nice policy to be polite while scraping.

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36'})

# %% [markdown]
# Then we define the base url to be used when querying the website. For this purpose I will just limit my search to Lisbon and sort by creation date. The address bar quickly updates and gives me the parameters sa=11 for Lisbon, and or=10 for the sorting, which I will use in the sapo variable.

# %%
sapo = "https://casa.sapo.pt/Venda/Apartamentos/?sa=11&or=10"
response = get(sapo, headers=headers)

# %% [markdown]
# And now we can test if we can communicate with the website. You can get several codes from this command, but if you get “200” it’s usually a sign that you’re good to go. You can see a list of these codes here.
# We can print the response and the first 1000 characters of the text.

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
#
# <html lang="pt">
# <head><title>
# 	Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, CASA SAPO - Portal Nacional de Imobiliário
# </title><meta name="author" content="CASA SAPO - Portal Nacional de Imobiliário - Janela Digital SA" />
#     <meta name="application-name" content="CASA SAPO - Portal Nacional de Imobiliário" data-copyright="Janela Digital SA" data-generated-time="19/03/2021 14:22" />
#
# <meta name="content-language" content="pt" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <meta name="description" content="Casas para Venda, 27783 Apartamentos Com Ofertas recentes no Distrito de Lisboa, Deseja comprar casa? No maior Portal Imobiliário Nacional temos milhares de apartamentos e moradias em Lisboa, no Porto e por todo o país." />
# <meta name="keywords" content="Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, venda, compra, comprar, casas, imóveis, apartamentos, moradias

# %% [markdown]
# Alright, we’re all set to start exploring whatever we get from the website. We need to define the Beautiful Soup object that will help us read this html. That’s what BS does: it picks the text from the response and parses the information in a way that makes it easier for you to navigate in its structure and get its contents.
# #Time to make some Soup!

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')
html_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt">
# <head><title>
# 	Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, CASA SAPO - Portal Nacional de Imobiliário
# </title><meta content="CASA SAPO - Portal Nacional de Imobiliário - Janela Digital SA" name="author"/>
# <meta content="CASA SAPO - Portal Nacional de Imobiliário" data-copyright="Janela Digital SA" data-generated-time="19/03/2021 14:22" name="application-name"/>
# <meta content="pt" name="content-language"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Casas para Venda, 27783 Apartamentos Com Ofertas recentes no Distrito de Lisboa, Deseja comprar casa? No maior Portal Imobiliário Nacional temos milhares de apartamentos e moradias em Lisboa, no Porto e por todo o país." name="description"/>
# <meta content="Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, venda, compra, comprar, casas, imóveis, apartamentos, moradias, terrenos, porto, lisboa" name="keywords"/>
# <meta content="always" name="referrer"/>
# <link href="/News/Multimedia/RSS/CNCS.rss" rel="alternate" title="Últimas Notícias CASA SAPO" type="application/rss+xml"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon.ico?v=2" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-57x57.png?v=2" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-60x60.png?v=2" rel="apple-touch-icon" sizes="60x60" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-72x72.png?v=2" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-76x76.png?v=2" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-114x114.png?v=2" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-120x120.png?v=2" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-144x144.png?v=2" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-152x152.png?v=2" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-180x180.png?v=2" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-36x36.png?v=2" rel="icon" sizes="36x36" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-48x48.png?v=2" rel="icon" sizes="48x48" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-96x96.png?v=2" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-192x192.png?v=2" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-16x16.png?v=2" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-32x32.png?v=2" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-16x16.png?v=2" rel="icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="index,follow" name="robots"/><meta content="index,follow" name="googlebot"/>
# <meta content="https://casa.sapo.pt/Themes/Global/Images/Social/logo_fb.png" itemprop="image" property="og:image"/><meta content="/browserconfig.xml" name="msapplication-config"/><meta content="#222222" name="theme-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#222222" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" rel="canonical"/>
# <link href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=2" rel="next"/>
# <link href="https://casa.sapo.pt/en_gb/buy-apartments/most-recent/district.lisboa/" hreflang="en" rel="alternate"/>
# <link href="https://casa.sapo.pt/es_es/comprar-pisos-apartamentos/ofertas-recientes/distrito.lisboa/" hreflang="es" rel="alternate"/>
# <link href="https://casa.sapo.pt/fr_fr/acheter-appartements/offres-recentes/quartier.lisboa/" hreflang="fr" rel="alternate"/>
# <link href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" hreflang="pt" rel="alternate"/>
# <link href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://vcs.egorealestate.com" rel="preconnect"/>
# <link href="https://vcs.imoguia.com" rel="preconnect"/>
# <script>
#             (function (w, d, s, l, i)
#             {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-583JN6Z');
#         </script>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "url": "https://casa.sapo.pt",
#         "potentialAction":
#             {
#             "@type": "SearchAction",
#             "target": "https://casa.sapo.pt/Pesquisar/?fs={search_term_string}",
#             "query-input": "required name=search_term_string"
#         },
#         "author":
#         {
#             "@context" : "http://schema.org",
#             "@type" : "Organization",
#             "name" : "CASA SAPO - Portal Nacional de Imobiliário",
#             "url" : "https://casa.sapo.pt",
#             "logo" : "https://casa.sapo.pt/Themes/Global/Images/Backgrounds/logo.png",
#             "sameAs" : [ "http://www.facebook.com/CasaSapo.pt", "http://plus.google.com/+casasapo" ]
#         }
#     }
#     </script>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "Organization",
#         "url": "https://casa.sapo.pt",
#         "logo" : "https://casa.sapo.pt/Themes/Global/Images/Backgrounds/logo.png",
#         "contactPoint": [
#             {
#                 "@type": "ContactPoint",
#                 "telephone": "+351-262840462",
#                 "contactType": "customer service"
#             }
#         ]
#     }
#     </script>
# <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.5.0/css/font-awesome.min.css" onload="this.onload=null; this.rel='stylesheet'" rel="preload"/><link as="font" crossorigin="" href="/ScriptsV2/fonts/font-casasapo-1_0/fonts/casasapo.woff?twhrni" rel="preload"/><link href="/Themes/Global/mainClass.min.css?Version=637514961128311526" rel="stylesheet"/><link as="style" href="/Themes/Global/frontpage.min.css?Version=637514961122053436" onload="this.onload=null; this.rel='stylesheet'" rel="preload"/><link as="style" href="/Themes/Global/globalAsync.min.css?Version=637514961122363822" onload="this.onload=null; this.rel='stylesheet'" rel="preload"/><link as="style" href="/Themes/Global/CreditoHabitacaoMBCP.min.css?Version=637514961115802172" onload="this.onload=null; this.rel='stylesheet'" rel="preload"/><link as="style" href="/Themes/Global/CreditoHabitacaoMBCP-Responsive.min.css?Version=637514961115802172" onload="this.onload=null; this.rel='stylesheet'" rel="preload"/>
# <script>
#         (function (w)
#         {
#             if (("serviceWorker" in navigator))
#             {
#                 w.addEventListener('load', function ()
#                 {
#                     try
#                     {
#                         var path = "/sw.min.js";
#
#                         var promise = navigator.serviceWorker.register(path);
#                         if (promise instanceof Promise)
#                         {
#                             promise.then(function (reg)
#                             {
#                                 reg.onupdatefound = function ()
#                                 {
#                                     reg.update();
#                                 };
#                             }, function (error)
#                             {
#                                 LogError(error, location.href, 0, 0, error);
#                             }).catch(function (error)
#                             {
#                                 LogError(error, location.href, 0, 0, error);
#                             });
#                         }
#                     }
#                     catch (e)
#                     {
#                         LogError(e.message, location.href, 0, 0, e);
#                     }
#                 });
#             }
#         })(window);
#     </script>
# <script>
#         var lingua = 'pt_PT';
#         var pageType = '13';
#         var basePath = '/';
#         var popupHeaderColor = "#71ac41";
#     </script>
# <script src="/ScriptsV2/site/asynchandler.min.js?Version=637514961126739507"></script>
# <script defer="" src="/ScriptsV2/site/header.min.js?Version=637514961126739507"></script>
# <script>
# var CSRFTokenName = '_CSRFTOKEN';
# var CSRFTokenValue = '';
# function CSRFSetup(){for(var t,i=$("form[method!='get']"),n=0;n<i.length;n++)t=$("#"+CSRFTokenName+n),t.length>0?t.val(CSRFTokenValue):$("<input type='hidden' id='"+CSRFTokenName+n+"' name='"+CSRFTokenName+"' value='"+CSRFTokenValue+"' />").appendTo(i[n]);$.ajaxSetup($.parseJSON('{ "headers": { "'+CSRFTokenName+'": "'+CSRFTokenValue+'" } }'))}function CSRFDresser(){$.ajax({url:"/AJAX/CSRFDresser.aspx",type:"GET",dataType:"text",async:!1,cache:!1,success:function(n){CSRFTokenValue=n}})}function CSRFLoadJQuery(n){var t=document.createElement("script"),i,r;t.src="https://code.jquery.com/jquery-1.12.4.min.js";t.setAttribute("integrity","sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=");t.setAttribute("crossorigin","anonymous");i=document.getElementsByTagName("head")[0];r=!1;t.onload=t.onreadystatechange=function(){r||this.readyState&&this.readyState!=="loaded"&&this.readyState!=="complete"||(r=!0,n(),t.onload=t.onreadystatechange=null,i.removeChild(t))};i.appendChild(t)}if(window.jQuery)$(function(){CSRFDresser();CSRFSetup();$(document).ajaxComplete(function(){CSRFSetup()})});else{var thisInHouseJQuery=!1;typeof $=="function"&&(thisInHouseJQuery=!0);CSRFLoadJQuery(function(){console.log("CSRF: jQuery não foi carregado de inicio, tentar (re)carregar!");typeof jQuery=="undefined"?console.log("CSRF: jQuery não foi carregado para poder fazer o CSRF Setup!"):(console.log("CSRF: jQuery foi carregado ("+(thisInHouseJQuery?"inhouse":"cdn")+") !"),CSRFDresser(),$(function(){CSRFSetup();$(document).ajaxComplete(function(){CSRFSetup()})}))})}</script></head>
# <body data-isforcedesktopversion="false" data-ispopup="false">
# <script>
#         (function (i, s, o, g, r, a, m)
#         {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function ()
#             {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-266700-31', 'auto');
#         ga('send', 'pageview');
#
#         var clientId = 'undefined';
#         ga(function (tracker)
#         {
#             clientId = tracker.get('clientId');
#             document.cookie = 'ga_cid=' + clientId;
#         });
#     </script>
# <script src="/ScriptsV3/VcsHandler.min.js?Version=637514961121592775"></script>
# <script>
#     var EgoGuid = '';
#     var UserKnownDate = '';
#     var MetabaseId = '';
#     var MetabaseIdForAds = new Array();
#     var VcsInputQueue = new VcsQueueHandler();
#
#     var _SA_DefaultToken = 'zp0aiPVfrUHN7288ub5t5A==';
#     var _SA_EgoUrl = '/APICall';
#     var _SA_NLToken = '';
#
#     function syncEGO(guid)
#     {
#         var sSADone = getCookie('SA_DONE_CS');
#         if (sSADone === '')
#         {
#             sToken = _SA_DefaultToken;
#             bDoneAlready = false;
#             if (hasLocalStorage())
#             {
#                 try
#                 {
#                     var storedToken = localStorage.getItem("vcsSmartAlert") || '';
#                     if (storedToken)
#                     {
#                         var arrData = storedToken.split('_');
#                         if (arrData.length > 1)
#                         {
#                             var sStoredToken = arrData[1] || '';
#                             if (bDoneAlready && sStoredToken !== '')
#                                 sToken = sStoredToken;
#                         }
#                     }
#                 }
#                 catch (e)
#                 {
#                     $(function ()
#                     {
#                         LogError(e.message, location.href, 0, 0, e);
#                     });
#                 }
#             }
#
#             $.ajax({
#                 url: _SA_EgoUrl,
#                 type: 'POST',
#                 data: {
#                     "action":"MI",
#                     "token": sToken,
#                     "guid": guid,
#                     "ntk": _SA_NLToken
#                 },
#                 dataType: 'json',
#                 async: true,
#                 cache: false,
#                 xhr: function ()
#                 {
#                     var xhr = $.ajaxSettings.xhr();
#                     var setRequestHeader = xhr.setRequestHeader;
#                     xhr.setRequestHeader = function (name, value)
#                     {
#                         if (name == '_CSRFTOKEN')
#                             return;
#                         setRequestHeader.call(this, name, value);
#                     }
#                     return xhr;
#                 },
#                 success: function (data, textStatus, jqXHR)
#                 {
#                     var sReturnedToken = data.response;
#                     if (hasLocalStorage())
#                     {
#                         try
#                         {
#                             if (sReturnedToken !== '' && sReturnedToken !== _SA_DefaultToken)
#                                 localStorage.setItem("vcsSmartAlert", guid + "_" + sReturnedToken);
#                         }
#                         catch (e)
#                         {
#                             $(function ()
#                             {
#                                 LogError(e.message, location.href, 0, 0, e);
#                             });
#                         }
#                     }
#                     setCookie('SA_DONE_CS', 1);
#                 },
#                 error: function (jqXHR, textStatus, errorThrown)
#                 {
#                     if (jqXHR.getAllResponseHeaders() !== '') //Verify if user did not canceled request by navigating outside this page
#                         LogError(errorThrown, this.url, 0, 0, this.type + ": " + this.data);
#                 }
#             });
#         }
#
#     }
#
#     function setAnalyticsCustomVar(guid, date, mbid)
#     {
#         EgoGuid = guid;
#         UserKnownDate = date;
#         MetabaseIdForAds = mbid.split(",");
#
#         if (MetabaseIdForAds.length > 0)
#             mbid = MetabaseIdForAds[0];
#
#         MetabaseId = mbid;
#
#         if (hasLocalStorage())
#         {
#             try
#             {
#                 var storedToken = localStorage.getItem("vcsToken");
#                 if (!storedToken || storedToken !== EgoGuid)
#                 {
#                     localStorage.setItem("vcsToken", EgoGuid);
#                 }
#             }
#             catch (e)
#             {
#                 $(function ()
#                 {
#                     LogError(e.message, location.href, 0, 0, e);
#                 });
#             }
#         }
#
#         VcsInputQueue.fillGuid(EgoGuid, mbid);
#
#         if (typeof (ga) !== 'undefined')
#         {
#             setAnalyticsTrackingUserId(EgoGuid);
#             ga('set', 'dimension1', guid);
#         }
#         $(function ()
#         {
#             syncEGO(EgoGuid);
#         });
#     }
#
#     function trackAnalyticsPageview(string)
#     {
#         if (typeof (ga) !== 'undefined')
#         {
#             setAnalyticsTrackingUserId(EgoGuid);
#             ga('send', 'pageview', string);
#         }
#     }
#
#     function trackAnalyticsEvent(category, action, label)
#     {
#         if (typeof (ga) !== 'undefined')
#         {
#             setAnalyticsTrackingUserId(EgoGuid);
#
#             if (label === undefined)
#                 ga('send', 'event', category, action);
#             else
#                 ga('send', 'event', category, action, label);
#         }
#     }
#
#     function setAnalyticsTrackingUserId(userId)
#     {
#         if (typeof (ga) !== 'undefined')
#         {
#             if (userId !== undefined && userId !== null && userId !== '')
#                 ga('set', 'userId', userId);
#         }
#     }
#
#     function setAnalyticsTrackingUserIdCookie(userId)
#     {
#         if (userId !== undefined && userId !== null && userId !== '')
#             document.cookie = 'ga_uid=' + userId;
#     }
#
#     (function ()
#     {
#         var src = "https://vcs.imoguia.com/GetUniqueClickGuid.aspx?callback=setAnalyticsCustomVar";
#
#         if (hasLocalStorage())
#         {
#             try
#             {
#                 var storedToken = localStorage.getItem("vcsToken");
#                 if (storedToken)
#                     src += "&VCSUID=" + storedToken;
#
#             } catch (e)
#             {
#                 $(function ()
#                 {
#                     LogError(e.message, location.href, 0, 0, e);
#                 });
#             }
#         }
#
#         var script = document.createElement("script");
#         script.src = src;
#         script.async = true;
#         document.body.appendChild(script);
#     })();
#
#     if (typeof setCookie !== "function")
#     {
#         function setCookie(sName, oValue, nDays)
#         {
#             nDays = nDays || 0;
#
#             var oDate = new Date();
#             if (nDays !== 0)
#                 oDate.setDate(oDate.getDate() + nDays);
#
#             document.cookie = sName + "=" + escape(oValue) + (nDays === 0 ? "" : ";expires=" + oDate.toGMTString()) + ";path=/;";
#         }
#     }
#
#     if (typeof getCookie !== "function")
#     {
#         function getCookie(sCookieName)
#         {
#             var a_all_cookies = document.cookie.split(';');
#             var a_temp_cookie = '';
#             var cookie_name = '';
#             var cookie_value = '';
#             var b_cookie_found = false;
#
#             for (var i = 0; i < a_all_cookies.length; i++)
#             {
#                 a_temp_cookie = a_all_cookies[i].split('=');
#                 cookie_name = a_temp_cookie[0].replace(/^\s+|\s+$/g, '');
#
#                 if (cookie_name === sCookieName)
#                 {
#                     b_cookie_found = true;
#                     if (a_temp_cookie.length > 1)
#                         cookie_value = unescape(a_temp_cookie[1].replace(/^\s+|\s+$/g, ''));
#                     return cookie_value;
#                 }
#                 a_temp_cookie = null;
#                 cookie_name = '';
#             }
#             if (!b_cookie_found)
#                 return '';
#         }
#     }
#
# </script>
# <div style="display: none">
# <script>
#             var google_conversion_id = 1071331951;
#             var google_conversion_label = "8UAXCNHVsgQQ7_Ts_gM";
#             var google_custom_params = window.google_tag_params;
#             var google_remarketing_only = true;
#         </script>
# <script src="https://www.googleadservices.com/pagead/conversion.js"></script>
# <noscript>
# <div style="display: inline;">
# <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1071331951/?value=0&amp;label=8UAXCNHVsgQQ7_Ts_gM&amp;guid=ON&amp;script=0" style="border-style: none;" width="1"/>
# </div>
# </noscript>
# </div>
# <script>
#         !function (f, b, e, v, n, t, s)
#         {
#             if (f.fbq) return; n = f.fbq = function ()
#             {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             }; if (!f._fbq) f._fbq = n;
#             n.push = n; n.loaded = !0; n.version = '2.0'; n.queue = []; t = b.createElement(e); t.async = !0;
#             t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)
#         }(window,
#             document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '309291376099875');
#         fbq('track', 'PageView');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=309291376099875&amp;ev=PageView&amp;noscript=1" style="display: none" width="1"/>
# </noscript>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P7LPLK" style="display: none; visibility: hidden" title="Google Tag Manager" width="0"></iframe>
# </noscript>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-583JN6Z" style="display: none; visibility: hidden" title="Google Tag Manager" width="0"></iframe>
# </noscript>
# <div id="bsu-placeholder" style="height: 60px; background-color: #111"></div>
# <script>
#             if (window.addEventListener) // W3C standard
#             {
#                 window.addEventListener('load', LoadBSU, false); // NB **not** 'onload'
#             }
#             else if (window.attachEvent) // Microsoft
#             {
#                 window.attachEvent('onload', LoadBSU);
#             }
#
#             function LoadBSU()
#             {
#                 setTimeout(function ()
#                 {
#                     var script = document.createElement('script');
#                     script.type = 'text/javascript';
#                     script.src = '//js.sapo.pt/Projects/bsuv3/js/bsuv3.min.js';
#                     script.setAttribute("id", "bsuScript");
#                     script.setAttribute("defer", "");
#                     script.setAttribute("data-theme", "dark");
#                     script.setAttribute("data-bg-color", "#111");
#                     script.setAttribute("data-width", "1140");
#                     script.setAttribute("data-country", "pt");
#                     script.setAttribute("data-partner", "true");
#                     script.setAttribute("data-social-facebook", "https://facebook.com/sapo");
#                     script.setAttribute("data-social-twitter", "https://twitter.com/sapo");
#                     script.setAttribute("data-social-instagram", "https://instagram.com/sapo");
#                     document.getElementsByTagName('head')[0].appendChild(script);
#                 }, 100);
#             };
#         </script>
# <div id="JDCookieNotifier"></div>
# <script data-bgcolor="#444" data-color="#fff" data-margintop="36px" data-roundclose="true" id="jdcn-bar-v1" src="/JDCookieNotifier/pt-PT/CookieNotifier.min.js"></script>
# <script>
#     var needsToCloseBox = false;
#     var isBotAreaOpened = false;
#     var willReload = false;
#     var isInAlert = false;
# </script>
# <div class="mainHeader SALES_SEARCH SearchMode">
# <div class="mainHeaderContainer">
# <div class="cs_logo_wrapper">
# <a class="headerLogo" href="/" id="MC_Header1_aHPLink" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Logo-Home-Page')" title="CASA SAPO - Portal Nacional de Imobiliário">
# <div class="cs-logo casasapo" title="CASA SAPO - Portal Nacional de Imobiliário"></div>
# <span class="slug">Portal Nacional de Imobiliário desde 2001</span>
# </a>
# </div>
# <a class="headerButton classifiedButton" href="/Inserir-Classificado?or=hb" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Botao-Gerir-Classificados');" target="_blank">Criar Anúncio!</a>
# <div class="headerMenu">
# <script>
#                     $(function ()
#                     {
#                         if (typeof _CheckIfUserIsLogged === "function")
#                             _CheckIfUserIsLogged();
#
#                         $('#personal_area_bot, #areaPessoalButton span').text(window.UserIsLogged ? 'Área Pessoal' : 'Entrar na Área Pessoal');
#                     });
#                 </script>
# <a class="areaPessoalButton" data-custom-class="areaPessoalCustom" data-type="personalArea" id="areaPessoalButton" onclick="OpenPinList_OnClick (this, false, event);" style="cursor: pointer;" title="Aceda à sua Área Pessoal">
# <i class="fa fa-user"></i>
# <span>Entrar na Área Pessoal</span>
# </a>
# <script>
#                 $(function ()
#                 {
#                     $("body").click(function (e)
#                     {
#                         if ((needsToCloseBox && $(".boxPinList").is(":visible")) && e.target.className !== "boxPinList")
#                             ClosePinList_OnClick(e, isBotAreaOpened);
#                     });
#
#                     $(".boxPinList").click(function (e)
#                     {
#                         e.stopPropagation();
#                     });
#                 });
#             </script>
# <a class="pinListButton" data-custom-class="pinListCustom" data-type="pinList" id="pinListButton" onclick="OpenPinList_OnClick (this, false, event);" style="cursor: pointer;" title="Lista de imóveis">
# <span class="propertyListNumber"></span>
# <i class="fa fa-list"></i>
# <span>Lista de imóveis</span>
# </a>
# <a class="langBoxOpen" data-custom-class="langBoxCustom" data-type="languages" onclick="OpenPinList_OnClick (this, false, event);" style="cursor: pointer;" title="Idioma">
# <i class="cs-flag pt_PT" title="Português"></i>
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </a>
# <div id="boxLangListContent" style="display: none;">
# <span class="">
# <a href="/en_gb/buy-apartments/most-recent/district.lisboa/">
# <i class="cs-flag en_GB"></i>  English<br/>
# </a>
# </span>
# <span class="">
# <a href="/fr_fr/acheter-appartements/offres-recentes/quartier.lisboa/">
# <i class="cs-flag fr_FR"></i>  Français<br/>
# </a>
# </span>
# <span class="">
# <a href="/es_es/comprar-pisos-apartamentos/ofertas-recientes/distrito.lisboa/">
# <i class="cs-flag es_ES"></i>  Español<br/>
# </a>
# </span>
# </div>
# <div class="boxPinList" id="boxPinList" style="position: absolute; top: 45px; color: #5A5E50; font-size: 13px; display: none; z-index: 999;">
# <div class="boxPinListArrow">
# <div class="boxPinListArrow2"></div>
# </div>
# <div class="boxPinListTitle">
# <a class="pinListClose" onclick="ClosePinList_OnClick(event);" style="cursor: pointer;" title="Fechar"><i class="fa fa-close"></i></a>
# <span id="PinListTitle"></span>
# </div>
# <div class="boxPinListContent" id="boxPinListContent"></div>
# </div>
# <div class="usersCounter" id="MC_Header1_divUsersOnline" style="display: none; cursor: pointer;">
# <i class="fa fa-eye"></i><span id="spanUsersOnline"></span>
# <script>
#                     var onlineUsersLoop = null;
#
#                     $(function ()
#                     {
#                         if (typeof loopOnlineUsers === "function")
#                         {
#                             loopOnlineUsers('MC_Header1_divUsersOnline', 'Neste momento existem', 'visitantes <strong>online</strong>');
#                             onlineUsersLoop = setInterval(function () { loopOnlineUsers('MC_Header1_divUsersOnline', 'Neste momento existem', 'visitantes <strong>online</strong>'); }, 90000); // 1 minuto e meio
#                         }
#                     })
#                 </script>
# </div>
# </div>
# </div>
# </div>
# <script defer="">
#     $(document).ready(function ()
#     {
#         var $wW = window.getWidth();
#         var bIsMenuVisible = ($(".mainNavigation .mobileTabLabel").is(":visible"));
#
#         if (bIsMenuVisible && $wW <= 640)
#         {
#             $.ajax({
#                 url: "/GespubProducts/MobileTopPannel.aspx",
#                 type: 'GET',
#                 data: 'PSHOW=50',
#                 dataType: 'html',
#                 cache: false,
#                 beforeSend: function (jqXHR, settings) { },
#                 success: function (data, textStatus, jqXHR)
#                 {
#                     $('#MobileTopPannel').html(data);
#                     if ($('#MobileTopPannel').html() !== '')
#                         $('#MobileTopPannel').show();
#                 },
#                 error: function (jqXHR, textStatus, errorThrown) { }
#             });
#         }
#     });
# </script>
# <div class="MobileTopPannel" id="MobileTopPannel" style="display: none;"></div>
# <div class="mainNavigation">
# <div class="mainNavigationContainer">
# <h2 class="mobileTabLabel active"><a href="/Venda/Apartamentos/?sa=11&amp;or=10" onclick="return false;"><span></span></a></h2>
# <h2 class="active">
# <a data-vars-onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Vendas');" href="/comprar/">
# <span>Casas para venda</span>
# </a>
# </h2>
# <h2 class="">
# <a href="/alugar/" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Arrendamento');">
# <span>Casas para alugar</span>
# </a>
# </h2>
# <h2 class="">
# <a href="/casas-banco/" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Imoveis-Banca');">
# <span>Imóveis da Banca</span>
# </a>
# </h2>
# <h2 class="">
# <a href="/alugar-casa-ferias/" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Arrendamento-Ferias');">
# <span>Casas de ferias</span>
# </a>
# </h2>
# <h2 class="">
# <a href="/negocio/" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Negocios');">
# <span>Negócios</span>
# </a>
# </h2>
# <h2 class=" rooms">
# <a href="/alugar-quartos/" onclick="trackAnalyticsEvent('Group-Navegacao', 'Action-Tab-Quartos');">
# <span>Quartos</span>
# </a>
# </h2>
# <script>
#                 $(document).ready(function ()
#                 {
#                     $('.millenniumHeaderBtn img').unveiler(/*{ onerror: OnImgError }*/);
#                 });
#             </script>
# <style>
#                 .millenniumHeaderBtn
#                 {
#                     display: inline-block;
#                     line-height: normal;
#                     text-align: center;
#                     font-size: 12px;
#                 }
#
#                     .millenniumHeaderBtn img
#                     {
#                         display: block;
#                         width: 135px;
#                         height: 30px;
#                         margin: 0 auto;
#                     }
#             </style>
# <h2 class=" millennium">
# <a href="/credito-habitacao/" onclick="">
# <span class="millenniumHeaderBtn">Quanto posso pedir
#                         <img alt="Millennium BCP" data-src="/Temas/Global/Parcerias/MillenniumBCP/bcp_logo.svg?V=1" src="..."/>
# </span>
# </a>
# </h2>
# </div>
# </div>
# <script>
#     $(document).ready(function ()
#     {
#         if ($(".mainNavigationContainer h2.active a").text() != "")
#             $(".mobileTabLabel").find("a span").empty().html($(".mainNavigationContainer h2.active a").text() + "<i class='fa fa-bars'></i>");
#         else
#             $(".mobileTabLabel").parents().find(".mainNavigation").addClass("hideTabs");
#
#         $(".mobileTabLabel").click(function ()
#         {
#             if ($(this).hasClass("openMenu"))
#             {
#                 $(this).parent().css("height", "50px");
#                 $(this).removeClass("openMenu");
#                 $("h2.active i").removeClass("fa-times");
#                 $("h2.active i").addClass("fa-bars");
#
#             }
#             else
#             {
#                 $(this).parent().css("height", "auto");
#                 $(this).addClass("openMenu");
#                 $("h2.active i").removeClass("fa-bars");
#                 $("h2.active i").addClass("fa-times");
#             }
#         })
#     });
#
# </script>
# <script>
#             $(document).ready(function ()
#             {
#                 trackAnalyticsEvent('Group-Listagem-Imoveis', 'Action-Listagem-Vendas');
#             });
#         </script>
# <div class="searchHeader SALES_SEARCH">
# <div class="searchHeaderContainer">
# <div class="searchHeaderMenu">
# <a id="toggleNormalSearch" onclick="toggleResponsiveFilter();" style="cursor: pointer;"><strong>Filtros</strong></a>
# <a data-fid="0" data-ftype="SEARCH" data-searchjson='{"sys":"1,2,3,5,6","mca":"1","bh":1,"sa":"11","or":10}' data-sptype="7" id="btnManageFavorite" onclick="ManageFavorite(this); trackAnalyticsEvent ('SearchPage', 'guardar-pesquisa');" style="cursor: pointer;">Guardar</a>
# <a id="toggleAdvSearch" style="cursor: pointer;">Pesquisa Avançada <span style="display: none; text-transform: lowercase;"></span></a>
# <a class="coolPopup pestanaAlerta" data-height="535" data-src="/AreaPessoal/PopUps/CreateAlert.aspx?mca=1&amp;sa=11&amp;bh=1&amp;or=10" data-title="Crie alerta" data-type="iframe" data-width="600" href="javascript:void(0)" id="mobileAlert">Crie alerta</a>
# </div>
# <a class="coolPopup pestanaAlerta" data-height="535" data-src="/AreaPessoal/PopUps/CreateAlert.aspx?mca=1&amp;sa=11&amp;bh=1&amp;or=10" data-title="Seja o primeiro. Receba novos imóveis" data-type="iframe" data-width="600" href="javascript:void(0)">
# <i aria-hidden="true" class="fa fa-angle-double-down"></i>
# <span>Seja o primeiro. Receba novos imóveis</span>
# <i aria-hidden="true" class="fa fa-angle-double-down"></i>
# </a>
# <h1 class="searchHeaderTitle">
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" title="Casas para Venda, 27783 Apartamentos Com Ofertas recentes no Distrito de Lisboa">
#                 Casas para Venda, 27783 Apartamentos Com Ofertas recentes no Distrito de Lisboa
#
#             </a>
# </h1>
# <h2 class="searchHeaderBreadCrumb">
# <a class="bcMenu" data-id="d7730339-a082-4eda-afbb-824703d2f5fd" href="/comprar-apartamentos/" title="Apartamentos">Apartamentos</a><span class="bcSubMenu" data-parent="d7730339-a082-4eda-afbb-824703d2f5fd"><ul><li><a href="/comprar-apartamentos/andar-de-predio/" title="Andar de Prédio">Andar de Prédio</a></li><li><a href="/comprar-apartamentos/apartamento/" title="Apartamento">Apartamento</a></li><li><a href="/comprar-apartamentos/apart-hotel/" title="Apart-Hotel">Apart-Hotel</a></li><li><a href="/comprar-apartamentos/duplex/" title="Duplex">Duplex</a></li><li><a href="/comprar-apartamentos/estudio/" title="Estúdio">Estúdio</a></li><li><a href="/comprar-apartamentos/flat/" title="Flat">Flat</a></li><li><a href="/comprar-apartamentos/loft/" title="Loft">Loft</a></li><li><a href="/comprar-apartamentos/penthouse/" title="Penthouse">Penthouse</a></li><li><a href="/alugar-quartos/" title="Quarto">Quarto</a></li><li><a href="/comprar-apartamentos/sala/" title="Sala">Sala</a></li><li><a href="/comprar-apartamentos/sala-de-condominio/" title="Sala de Condomínio">Sala de Condomínio</a></li><li><a href="/comprar-apartamentos/sotao/" title="Sótão">Sótão</a></li><li><a href="/comprar-apartamentos/terreo/" title="Térreo">Térreo</a></li><li><a href="/comprar-apartamentos/vivenda-de-primeiro-andar/" title="Vivenda de Primeiro Andar">Vivenda de Primeiro Andar</a></li></ul></span> <i aria-hidden="true" class="fa fa-angle-right"></i> <a class="bcMenu" data-id="de815767-c062-421d-8a10-6597d0a9a36f" href="/comprar-apartamentos/distrito.lisboa/" title="Apartamentos, no Distrito de Lisboa">Distrito de Lisboa</a><span class="bcSubMenu" data-parent="de815767-c062-421d-8a10-6597d0a9a36f"><ul><li><a href="/comprar-apartamentos/alenquer/" title="Apartamentos em Alenquer">Alenquer</a></li><li><a href="/comprar-apartamentos/amadora/" title="Apartamentos na Amadora">Amadora</a></li><li><a href="/comprar-apartamentos/arruda-dos-vinhos/" title="Apartamentos em Arruda dos Vinhos">Arruda dos Vinhos</a></li><li><a href="/comprar-apartamentos/azambuja/" title="Apartamentos na Azambuja">Azambuja</a></li><li><a href="/comprar-apartamentos/cadaval/" title="Apartamentos no Cadaval">Cadaval</a></li><li><a href="/comprar-apartamentos/cascais/" title="Apartamentos em Cascais">Cascais</a></li><li><a href="/comprar-apartamentos/lisboa/" title="Apartamentos em Lisboa">Lisboa</a></li><li><a href="/comprar-apartamentos/loures/" title="Apartamentos em Loures">Loures</a></li><li><a href="/comprar-apartamentos/lourinha/" title="Apartamentos na Lourinhã">Lourinhã</a></li><li><a href="/comprar-apartamentos/mafra/" title="Apartamentos em Mafra">Mafra</a></li><li><a href="/comprar-apartamentos/odivelas/" title="Apartamentos em Odivelas">Odivelas</a></li><li><a href="/comprar-apartamentos/oeiras/" title="Apartamentos em Oeiras">Oeiras</a></li><li><a href="/comprar-apartamentos/sintra/" title="Apartamentos em Sintra">Sintra</a></li><li><a href="/comprar-apartamentos/sobral-de-monte-agraco/" title="Apartamentos em Sobral de Monte Agraço">Sobral de Monte Agraço</a></li><li><a href="/comprar-apartamentos/torres-vedras/" title="Apartamentos em Torres Vedras">Torres Vedras</a></li><li><a href="/comprar-apartamentos/vila-franca-de-xira/" title="Apartamentos em Vila Franca de Xira">Vila Franca de Xira</a></li></ul></span>
# </h2>
# </div>
# </div>
# <script>
#         var alertForm800Done = false;
#
#         $(function ()
#         {
#             var handleAnchorWidth = function ()
#             {
#                 var count = $(".searchHeaderMenu a:visible").length;
#                 if (count > 0)
#                     $(".searchHeaderMenu a:visible").css("width", "calc(" + (100 / count).toFixed(0) + "% - 30px)");
#             }
#
#             var inView = function (element)
#             {
#                 var $e = $(element);
#                 var $w = $(window);
#                 var th = 0;
#                 if ($e.is(":hidden")) return;
#
#                 var wt = $w.scrollTop(),
#                     wb = wt + $w.height(),
#                     et = $e.offset().top,
#                     eb = et + $e.height();
#
#                 return eb >= wt - th && et <= wb + th;
#             }
#
#             var handleResize = function ()
#             {
#                 var $menu = $(".searchHeaderMenu");
#                 if ($(window).width() <= 640)
#                 {
#
#                     var $topLimit = $(".searchHeader");
#                     var $bottomLimit = $(".paginador");
#                     if ($topLimit.length && $bottomLimit.length)
#                     {
#                         $(document).on('scroll', function ()
#                         {
#                             if (!inView($(".footerContainer")) && ($(window).scrollTop() < $(".footerContainer").offset().top + $menu.height()))
#                             {
#                                 if (!inView($topLimit) && !$menu.hasClass("fixed") && (($topLimit.scrollTop() + 50) < $(window).scrollTop()))
#                                 {
#                                     $menu.addClass("fixed");
#                                     var count = $(".searchHeaderMenu a:visible").length;
#                                     if (count > 0)
#                                     {
#                                         $(".searchHeaderMenu a:visible").css({
#                                             "width": "calc(" + (100 / count).toFixed(0) + "% - 5px)",
#                                             "padding": 0
#                                         });
#                                     }
#                                 }
#                                 else if (inView($topLimit) && $menu.hasClass("fixed"))
#                                 {
#                                     $menu.removeClass("fixed");
#                                 }
#                             } else
#                                 $menu.removeClass("fixed");
#                         });
#                     }
#                 } else
#                 {
#                     $menu.removeClass("fixed");
#                     $(document).off('scroll');
#                     $(".searchHeaderMenu a:visible").css("width", "");
#                 }
#             }
#
#             if ($(window).width() <= 640)
#             {
#                 handleAnchorWidth();
#             }
#
#             handleResize();
#             $(window).resize(handleResize);
#
#
#             function getAlertMobileForm()
#             {
#                 if (!alertForm800Done && $(window).width() <= 800 && $("#formCreateAlert").length === 0)
#                 {
#                     $.ajax({
#                         url: "/AJAX/SearchPage/MobileAlertForm.aspx?mca=1&sa=11&bh=1&or=10",
#                         method: "GET",
#                         success: function (data)
#                         {
#                             $(".paginadorText:first").append(data);
#
#                             $.CasaSapoUI();
#                             $("#BtnCreateAlert").css("color", "#fff");
#
#                             alertForm800Done = true;
#
#                         },
#                         error: function (jqXHR, textStatus, errorThrown)
#                         {
#                             if (jqXHR.getAllResponseHeaders() !== '')/*Verify if user did not canceled request by navigating outside this page*/
#                                 LogError(errorThrown, this.url, 0, 0, this.type + ": " + this.data);
#                         }
#                     });
#                 }
#             }
#
#             getAlertMobileForm();
#             $(window).resize(getAlertMobileForm);
#
#             if ($.istouch())
#                 $(".bgSelectSwitch").addClass("mobile");
#
#             $(window).scroll(UpdateSearchHeader, closeActiveBCMenu).trigger("scroll");
#             $(window).resize(closeActiveBCMenu);
#             $("body").on("click", closeActiveBCMenu);
#             CheckFavorite();
#
#             var shtw = parseInt($(".searchHeaderTitle").css("width")) - 15;
#             $(".searchHeaderBreadCrumb a").css("max-width", shtw);
#             $(".searchHeaderBreadCrumb a").on("click", function ()
#             {
#                 var label = $(this).attr("title");
#                 trackAnalyticsEvent('Group-Navegacao', 'Action-Click-BreadCrumb', label);
#             });
#
#             $(".bcSubMenu").hover(null, closeActiveBCMenu);
#
#             $(".bcMenu").hover(
#                 function ()
#                 {
#                     closeActiveBCMenu();
#
#                     var $id = $(this).data("id");
#                     $(".searchHeaderBreadCrumb").data("menuOpen", $id);
#                     bcPositionMenu(this);
#                 },
#                 function ()
#                 {
#                     $id = $(this).data("id");
#                     $sub = $(".bcSubMenu[data-parent='" + $id + "']");
#                 }
#             );
#         });
#
#         function bcPositionMenu(ele)
#         {
#             $id = $(ele).data("id");
#             $parent = $(".bcMenu[data-id='" + $id + "']");
#             $sub = $("[data-parent='" + $id + "']");
#             if ($sub.length > 0)
#             {
#                 $parent.addClass("active");
#                 $bottom = $(ele).position().top + $(ele).outerHeight(true);
#                 $left = $(ele).position().left;
#                 $sub.css({ "top": $bottom, "left": $left, 'display': 'inline-block' });
#             }
#             var shtw = parseInt($(".searchHeaderTitle").css("width")) - 15;
#             $(".searchHeaderBreadCrumb a").css("max-width", shtw);
#         }
#
#         function closeActiveBCMenu()
#         {
#             var openid = $(".searchHeaderBreadCrumb").data("menuOpen");
#             if (typeof openid !== "undefined")
#             {
#                 $(".bcMenu[data-id='" + openid + "']").removeClass("active");
#                 $sub = $(".bcSubMenu[data-parent='" + openid + "']");
#                 $sub.hide();
#             }
#             if (window.getWidth() > 640)
#             {
#                 $(".searchHeaderMenu a").css({ "height": $(".searchHeaderContainer").css("height"), "line-height": $(".searchHeaderContainer").css("height") })
#                 $(".searchHeaderMenu a").css("border-bottom", "none");
#             }
#         }
#     </script>
# <div class="bbSapo" style="text-align: center;">
# <div data-pub="sas" data-pub-lazy="false" data-pub-type="inline" data-sas-formatid="38559" data-sas-pageid="632551" data-sas-siteid="95475" data-sas-target="slug=/Imoveis_Venda.aspx"></div>
# </div>
# <div class="lastSearch-container hidden" id="lastSearch">
# <div class="lastSearch-wrapper clearfix">
# <a class="searchLink" onclick="trackAnalyticsEvent('Group-Listagem-Imoveis', 'Action-Efeito-Memoria-SALES_SEARCH')" style="cursor: pointer">A sua última pesquisa: <span id="context"></span></a>
# <a class="closeLastSearch" style="cursor: pointer" title="Fechar">
# <span>Fechar</span><i class="fa fa-times-circle-o"></i>
# </a>
# </div>
# </div>
# <script>
#     $(function ()
#     {
#         $.ajax({
#             url: '/AJAX/SearchPage/MemorySearch.aspx?mca=1&sa=11&bh=1&or=10&count=27783&pt=13&action=1',
#             method: "POST",
#             success: function (res)
#             {
#                 if (res)
#                 {
#                     $("#lastSearch .searchLink").attr("href", res.url);
#                     $("#context").text(res.context);
#                     $("#lastSearch").slideDown("slow");
#                 }
#             },
#             error: function (jqXHR, textStatus, errorThrown)
#             {
#                 if (jqXHR.getAllResponseHeaders() !== '')/*Verify if user did not canceled request by navigating outside this page*/
#                     LogError(errorThrown, this.url, 0, 0, this.type + ": " + this.data);
#             }
#         });
#
#         $("#lastSearch .closeLastSearch").click(function (e)
#         {
#             e.preventDefault();
#
#             $.ajax({
#                 url: '/AJAX/SearchPage/MemorySearch.aspx?pt=13&action=2',
#                 method: "POST",
#                 success: function ()
#                 {
#                     $("#lastSearch").slideUp("slow", function ()
#                     {
#                         $("#lastSearch").remove();
#                     });
#                 },
#                 error: function (jqXHR, textStatus, errorThrown)
#                 {
#                     if (jqXHR.getAllResponseHeaders() !== '')/*Verify if user did not canceled request by navigating outside this page*/
#                         LogError(errorThrown, this.url, 0, 0, this.type + ": " + this.data);
#                 }
#             });
#         })
#     });
# </script>
# <div class="searchSimilarSearches">
# <div class="searchSimilarSearchesContainer">
# <h2>
# <a href="/comprar-apartamentos/distrito.lisboa/com-acesso-mobilidade-reduzida/" title="Casas para Venda, Apartamentos no Distrito de Lisboa, com acesso mobilidade reduzida">Casas para Venda, Apartamentos no Distrito de Lisboa, com acesso mobilidade reduzida</a>
# </h2>
# <h2>
# <a href="/comprar-apartamentos/distrito.lisboa/com-garagem-estacionamento/" title="Casas para Venda, Apartamentos no Distrito de Lisboa, com garagem/estacionamento">Casas para Venda, Apartamentos no Distrito de Lisboa, com garagem/estacionamento</a>
# </h2>
# </div>
# </div>
# <script>
#     var uris = ["//vcs.imoguia.com/VCS.aspx?tick=637517605509828892&K=StatsMPCasaSapoPTSearches&H=T%3dS%3bMCA%3d1%3bCA%3d0%3bBU%3d1%3bST%3d-1%3bSA%3d11%3bTW%3d0%3bNH%3d0%3bTUR%3d0%3bLMPR%3d0%3bGMPR%3d0%3bLP%3d0%3bGP%3d0%3bLAU%3d0%3bGAU%3d0%3bOR%3d10", "//vcs.imoguia.com/VCS.aspx?tick=637517605509828892&K=StatsMPCasaSapoPTSearchesWithResults&H=T%3dSWR%3bMCA%3d1%3bCA%3d0%3bCT%3d620%3bSA%3d11%3bTW%3d0%3bNH%3d0%3bZO%3d0%3bTUR%3d0%3bShape%3d00000000-0000-0000-0000-000000000000%3bBU%3d1%3bST%3d-1%3bLMPR%3d0%3bGMPR%3d0%3bLP%3d0%3bGP%3d0%3bLY%3d0%3bGY%3d0%3bLAU%3d0%3bGAU%3d0%3bOR%3d10%3bFT%3d0%3bGEO%3d0%3bVT%3d0%3bREF%3d%3bND%3d0%3bPDP%3d0%3bPDT%3d0%3bECV%3d%3bFS%3d%3bPN%3d1%3bNR%3d27783"];
#
#     for (var i = 0; i < uris.length; i++)
#     {
#         var uri = uris[i];
#         var uid = typeof GetVCSUID === "function" ? GetVCSUID() : EgoGuid;
#         uri += "&VCSUID=" + uid;
#         var script = document.createElement("script");
#         script.src = uri;
#         script.async = true;
#         document.body.appendChild(script);
#     }
# </script>
# <div class="searchContent">
# <div class="searchSidebar">
# <div class="searchFilter" style="z-index: 100;">
# <style>
#     #tabsLocation.ui-tabs #ui-id-2 span
#     {
# ...
# <div class="paginador">
# <span class="paginadorPrevious disabledBtn" id="MC_Paginator_LinkPreviousInactive">« Anterior</span>
# <a class="paginadorNext" href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=2" id="MC_Paginator_LinkNextActive">Seguinte »</a>
# <p>
# <span class="currentPage">
#             1
#         </span>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=2" id="MC_Paginator_RepGreaterPages_LinkY_0">2</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=3" id="MC_Paginator_RepGreaterPages_LinkY_1">3</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=4" id="MC_Paginator_RepGreaterPages_LinkY_2">4</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=5" id="MC_Paginator_RepGreaterPages_LinkY_3">5</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=6" id="MC_Paginator_RepGreaterPages_LinkY_4">6</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=7" id="MC_Paginator_RepGreaterPages_LinkY_5">7</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=8" id="MC_Paginator_RepGreaterPages_LinkY_6">8</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=9" id="MC_Paginator_RepGreaterPages_LinkY_7">9</a>
# <a href="/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=10" id="MC_Paginator_RepGreaterPages_LinkY_8">10</a>
#
#          ...
#
#     </p>
# </div>
# </div>
# <p class="paginadorText" style="margin: 25px 0;">
#                         Veja mais Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa<br/>
# <br/>
#                         Tipologia : <a href="/comprar-apartamentos/t0/distrito.lisboa/" title="Apartamentos T0, Distrito de Lisboa">T0</a> | <a href="/comprar-apartamentos/t1/distrito.lisboa/" title="Apartamentos T1, Distrito de Lisboa">T1</a> | <a href="/comprar-apartamentos/t2/distrito.lisboa/" title="Apartamentos T2, Distrito de Lisboa">T2</a> | <a href="/comprar-apartamentos/t3/distrito.lisboa/" title="Apartamentos T3, Distrito de Lisboa">T3</a> | <a href="/comprar-apartamentos/t4/distrito.lisboa/" title="Apartamentos T4, Distrito de Lisboa">T4</a> | <a href="/comprar-apartamentos/t5/distrito.lisboa/" title="Apartamentos T5, Distrito de Lisboa">T5</a> | <a href="/comprar-apartamentos/t6-ou-superior/distrito.lisboa/" title="Apartamentos T6 ou superior, Distrito de Lisboa">T6 ou superior</a><br/>
#                         Zonas : <a href="/comprar-apartamentos/lisboa/avenidas-novas/arredores-(sao-sebastiao-da-pedreira)/?zo=16346" title="Apartamentos, Lisboa, Avenidas Novas, Arredores (São Sebastião da Pedreira)">Arredores (São Sebastião da Pedreira)</a> | <a href="/comprar-apartamentos/lisboa/avenidas-novas/picoas-(sao-jorge-de-arroios)/?zo=12353" title="Apartamentos, Lisboa, Avenidas Novas, Picoas (São Jorge de Arroios)">Picoas (São Jorge de Arroios)</a> | <a href="/comprar-apartamentos/lisboa/avenidas-novas/sete-rios-(sao-sebastiao-da-pedreira)/?zo=12399" title="Apartamentos, Lisboa, Avenidas Novas, Sete Rios (São Sebastião da Pedreira)">Sete Rios (São Sebastião da Pedreira)</a><br/>
# <br/>
# <a href="/imobiliarias/distrito.lisboa/" title="Agências Imobiliárias no Distrito de Lisboa">Agências Imobiliárias no Distrito de Lisboa</a><br/>
# </p>
# <p class="paginadorText">
#                     Ainda não encontrou o imóvel que procura?
#                     <a href="/general/procuro.aspx?mca=1&amp;sa=11&amp;bh=1&amp;or=10" onclick="trackAnalyticsEvent ('SearchPage', 'pedido-procuro-listagem');" title="Ainda não encontrou o imóvel que procura? clique aqui e deixe o seu pedido">clique aqui e deixe o seu pedido</a>
# </p>
# <script>
#                     function saveSearch()
#                     {
#                         trackAnalyticsEvent('SearchPage', 'pedido-procuro-listagem');
#                         if (typeof localStorage === "undefined")
#                             return true;
#                         localStorage.setItem("lastSearch", location.href);
#                         return true;
#                     }
#                 </script>
# </div>
# <script>
#         var ampParam = '';
#         var galleryFile = basePath + "ScriptsV2/gallery.min.js?Version=637514961091582522";
#         var spCurrent = '?mca=1&sa=11&bh=1&or=10'.replace('?', '');
#         var versionWS = '637158949981236489';
#         var prevNextKey = 'CS_PN_REALESTATES';
#     </script>
# <div class="mainSectionNav SiteRelatedLinks">
# <div class="mainSectionNavContainer">
# <div class="mainSectionNavLinks">
# <div class="fullSections">
# <p class="sectionNavTitle">
#                     Áreas CASA<b>SAPO</b>
# </p>
# <a href="/Classificados/" onclick="trackAnalyticsEvent('HomePage', 'gerir-classificado');" rel="noopener" target="_blank" title="Gerir Classificado">Gerir Classificado</a>
# <a href="/pesquisas-frequentes/" onclick="trackAnalyticsEvent('HomePage', 'pesquisas-frequentes');" title="Pesquisas Frequentes">Pesquisas Frequentes</a>
# <a href="/noticias/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-noticias');" title="CASASAPO Notícias">CASA<b>SAPO</b> Notícias</a>
# <a href="/general/divulgacao_internet.aspx" onclick="trackAnalyticsEvent('HomePage', 'link-profissionais');" title="Como Divulgar">Como Divulgar</a>
# <a href="/general/estatisticas/indicadores.aspx" onclick="trackAnalyticsEvent('HomePage', 'indicadores');" title="Indicadores CASASAPO">Indicadores CASA<b>SAPO</b></a>
# <a href="https://www.egorealestate.com/CasaSapo" onclick="trackAnalyticsEvent('HomePage', 'link-profissionais');" rel="noopener" target="_blank" title="Profissionais">Profissionais</a>
# <a href="http://imoavaliacao.imoguia.com" onclick="trackAnalyticsEvent('HomePage', 'imoavaliacao');" rel="noopener" target="_blank" title="Avaliação de Imóveis">Avaliação de Imóveis</a>
# <a href="/imobiliarias/" onclick="trackAnalyticsEvent('HomePage', 'agentes-imobiliarios');" title="Imobiliárias">Imobiliárias</a>
# <a class="areaPessoalButton" data-custom-class="areaPessoalCustom bottom" data-type="personalArea" id="personal_area_bot" onclick="OpenPinList_OnClick(this, false, event)" style="cursor: pointer;" title="Aceda à sua Área Pessoal">Entrar na Área Pessoal</a>
# <div class="boxPinList" id="boxPinList_bot" style="position: absolute; z-index: 999; display: none;">
# <div class="boxPinListArrow">
# <div class="boxPinListArrow2"></div>
# </div>
# <div class="boxPinListTitle">
# <a class="pinListClose" onclick="ClosePinList_OnClick(event, true);" style="cursor: pointer;" title="Fechar"><i class="fa fa-close"></i></a>
# <span id="PinListTitle_bot"></span>
# </div>
# <div class="boxPinListContent" id="boxPinListContent_bot"></div>
# </div>
# <a href="http://www.facebook.com/CasaSapo.pt" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-Facebook');" rel="noopener" target="_blank" title="Facebook CASASAPO">Facebook CASA<b>SAPO</b></a>
# <a href="https://barometro.casa.sapo.pt" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-Barometro');" rel="noopener" target="_blank" title="Barómetro CASASAPO">Barómetro CASA<b>SAPO</b></a>
# <a href="/general/reformaarrendamento/simulador.aspx" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-NRAU');" rel="noopener" target="_blank" title="NRAU - Simulador">NRAU - Simulador</a>
# <a href="/alugar-quartos/" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-Quartos');" title="Quartos">Quartos</a>
# <a href="https://www.rentals.pt/pt-PT" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-Rentals');" rel="noopener" target="_blank" title="Rentals.pt, o portal com os melhores preços no arrendamentos para férias em Portugal">Casas de Férias - Rentals.pt</a>
# <a href="/sil/2019.aspx" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-2016');" title="Salão Imobiliário - SIL 2020">Salão Imobiliário - SIL 2020</a>
# </div>
# <div class="halfSections">
# <p class="sectionNavTitle">Internacional</p>
# <a href="https://casasapo.es/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-es');" rel="noopener" target="_blank" title="Espanha">Espanha</a>
# <a href="https://brasil.casa.sapo.pt/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-br');" rel="noopener" target="_blank" title="Brasil">Brasil</a>
# <a href="https://casa.sapo.ao/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-ao');" rel="noopener" target="_blank" title="Angola">Angola</a>
# <a href="https://casa.sapo.cv/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-cv');" rel="noopener" target="_blank" title="Cabo Verde">Cabo Verde</a>
# <a href="https://casa.sapo.mz/" onclick="trackAnalyticsEvent('HomePage', 'casasapo-mz');" rel="noopener" target="_blank" title="Moçambique">Moçambique</a>
# </div>
# <div class="halfSections2">
# <p class="sectionNavTitle">Parceiros</p>
# <a href="/general/reformaarrendamento/reformaarrendamento.aspx" onclick="trackAnalyticsEvent('HomePage', 'reforma-arrendamento');" rel="noopener" target="_blank" title="Reforma do Arrendamento Urbano">Reforma do Arrendamento Urbano</a>
# </div>
# </div>
# </div>
# </div>
# <div class="footer">
# <script>$(function () { $(".lazy img").unveiler(); });</script>
# <div class="footerContainer">
# <a class="egoLogo lazy" href="https://www.egorealestate.com/CasaSapo" onclick="trackAnalyticsEvent('Footer', 'EgoLogo');" rel="noopener" target="_blank">
# <span>Exclusivo</span>
# <br/>
# <img alt="eGO" data-src="/Themes/Global/Images/Backgrounds/ego.svg" src="..."/>
# </a>
# <a class="JDLogo lazy" href="https://www.janeladigital.com" onclick="trackAnalyticsEvent('Footer', 'jd-logo');" rel="noopener" target="_blank">
# <img alt="Janela Digital" data-src="/Themes/Global/Images/Backgrounds/bg_jd_altice.png" src="..."/>
# </a>
# <p class="footerLinks">
# <a href="/general/quemsomos.aspx" onclick="trackAnalyticsEvent('Footer', 'Quem-Somos');" title="Acerca de nós">Quem somos</a>
# <a href="/imoveis.aspx" onclick="trackAnalyticsEvent('Footer', 'Pag-Imoveis');" title="Imóveis">Imóveis</a>
# <a href="https://www.netbox.pt" rel="noopener" target="_blank" title="NetBox">NetBox</a>
# <a href="/general/contacto.aspx" onclick="trackAnalyticsEvent('Footer', 'Form-Contacte-nos');" title="Faça-nos as suas questões">Contacte-nos</a>
# <a href="https://www.rentals.pt/pt-PT" onclick="trackAnalyticsEvent('Footer');" rel="noopener" target="_blank" title="Rentals.pt, o portal com os melhores preços no arrendamentos para férias em Portugal">Rentals.pt</a>
# <a href="/general/politicadeprivacidade.aspx" onclick="trackAnalyticsEvent('Footer', 'termos-e-condicoes');" title="Política de privacidade">Política de privacidade</a>
# <span class="link" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-SwitchToDesktop'); SwitchVersion();" style="cursor: pointer;" title="Versão Desktop">Versão Desktop</span>
# <a href="/general/recrutamento.aspx" onclick="trackAnalyticsEvent('Group-Areas-CasaSapo', 'Action-Recrutamento');" style="cursor: pointer;" title="Emprego">Emprego</a>
# </p>
# <p class="footerMidLinks">
# <a href="/en_gb/buy-apartments/most-recent/district.lisboa/">English</a>
# <a href="/fr_fr/acheter-appartements/offres-recentes/quartier.lisboa/">Français</a>
# <a href="/es_es/comprar-pisos-apartamentos/ofertas-recientes/distrito.lisboa/">Español</a>
# </p>
# <p class="footerSubLinks">
# <a href="/general/condicoes/condicoes_portal.aspx" onclick="trackAnalyticsEvent('Footer', 'condicoes-gerais'); window.popup({ title: 'CASA SAPO - Portal Nacional de Imobiliário', source: 'IFRAME', url: '/general/condicoes/condicoes_portal.aspx', width: window.innerWidth - 50, height: window.innerHeight - 50, visiblescreen: true }); return false;" rel="noopener" target="_blank">Condições Gerais de Utilização do Portal CASA<b>SAPO</b></a>
# <a href="https://www.livroreclamacoes.pt" onclick="trackAnalyticsEvent('Footer', 'LivroReclamacoes');" rel="noopener" target="_blank">Livro de Reclamações online</a>
# <a href="https://www.janeladigital.com" onclick="trackAnalyticsEvent('Footer', 'jd-link');" rel="noopener" target="_blank">Produzido por Janela Digital S.A. © Todos os direitos Reservados</a>
# </p>
# </div>
# </div>
# <script>
#         $(document).ready(function ()
#         {
#             if (false)
#                 $('body').css({ 'min-width': '1140px' });
#
#         });
#     </script>
# <script>
#         $(document).ready(function ()
#         {
#             $("#divMapContainer, .searchHeader").css({ "background-attachment": "scroll", "background-position": "center center" });
#         });
#     </script>
# <script>
#         $(document).ready(function ()
#         {
#             var referrer = document.referrer;
#             if (referrer === '' || !IsInIframe())
#                 return;
#
#             if (referrer.indexOf('sapo.pt') == -1
#                 && referrer.indexOf('sapo.cv') == -1
#                 && referrer.indexOf('sapo.ao') == -1
#                 && referrer.indexOf('sapo.mz') == -1
#                 && referrer.indexOf('casasapo.pt') == -1
#                 && referrer.indexOf('casasapo.es') == -1
#                 && referrer.indexOf('casaiol.pt') == -1
#                 && referrer.indexOf('iol.pt') == -1
#                 && referrer.indexOf('janeladigital.com') == -1
#                 && referrer.indexOf('localhost') == -1
#                 && referrer.indexOf('mitula.pt') == -1
#             )
#             {
#                 trackAnalyticsEvent('Group-UnAuthorized', referrer);
#                 setTimeout(function () { window.top.location.href = window.self.location.href; }, 250);
#             }
#         });
#     </script>
# <script defer="" src="/ScriptsV3/lib/jquery@3.5.1/jquery.min.js?Version=637438804588131780"></script>
# <script defer="" src="/ScriptsV2/site/systemdata.js.aspx?Version=637515030040646702"></script>
# <script defer="" src="/ScriptsV3/bundles/jquery.min.js?Version=637514961118770065"></script>
# <script defer="" src="/ScriptsV3/bundles/core.min.js?Version=637514961123155570"></script>
# <script defer="" src="/ScriptsV3/bundles/app.min.js?Version=637514961110176287"></script>
# <script>
#             document.addEventListener("DOMContentLoaded", function (event)
#             {
#                 var hp = 'Promise' in window; if (hp)
#                 {
#                     readyQ = readyQ.reduce(function (prev, curr)
#                     {
#                         prev.push(new Promise(function (resolve)
#                         {
#                             return resolve($(curr));
#                         }));
#
#                         return prev;
#                     }, []);
#                 }
#
#                 var queue = readyQ.chunk(Math.floor(readyQ.length / 2));
#                 if (hp)
#                 {
#                     Promise.all(queue);
#                 } else
#                 {
#                     queue.forEach(function (x)
#                     {
#                         x.forEach(function (y)
#                         {
#                             $(y);
#                         });
#                     });
#                 }
#                 delete readyQ;
#             });
#         </script>
# <script>
#             $(document).ready(function ()
#             {
#                 if (getCookie('IsRetina') != '1' && (window.devicePixelRatio === undefined ? 1 : window.devicePixelRatio) > 1)
#                     setCookie('IsRetina', '1', 90);
#             });
#         </script>
# <script>
#             (function (w, d, s, l, i)
#             {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-P7LPLK');
#         </script>
# </body>
# </html>

# %% [markdown]
# Before extracting the price, we want to be able to identify each result in the page. In order to know what tags we need to call, we can follow them from the price tag to the top until we reach something that looks like the main container for each result. We can see it below:

# %%
house_containers = html_soup.find_all('div', class_="searchResultProperty")

# %% [markdown]
# We now have an object that can be iterated while we scrape the results in each search page. Let’s try and get the price we saw before. I’ll define the variable first which will be the structure of our first house (picked up from the house_containers variable).

# %%
first = house_containers[0]
first.find_all('span')
# Out:
# [<span class="titleG3"></span>, <span>
#                          Apartamento T2, Póvoa de Santa Iria e Forte da Casa, Vila Franca de Xira, Lisboa
#                      </span>, <span class="btnContactPVPI" id="MC_PropertyInList_repProperties_btnContactPVPINormal_0" onclick="ShowContactForm('c17a5cf3-88b9-11eb-9c85-060000000052', '13', '5', true, false, '0'); return false;" style="z-index: 9999;" title="Contacte Anunciante">Contacte Anunciante</span>, <span>210 000 <strong title="Euro">€</strong></span>]

# %% [markdown]
# So the price is quite easily obtainable, but there are some special characters along the text. A simple way to take care of it is to simply replace the special character with nothing. I’ll break it down below, as I transform the string into an integer.

# %%
var_1 = first.find_all('span')[3].text
var_1
# Out:
# '210\xa0000 €'

# %%
var_1 = var_1.replace('\xa0','')
var_1
# Out:
# '210000 €'

# %%
var_1 = int(''.join(itertools.takewhile(str.isdigit,var_1)))
print(var_1,type(var_1))
# Out:
# 210000 <class 'int'>

# %% [markdown]
# In this last step, itertools helped me retrieve only the digits from the second step. We just scraped our first price! The other fields we want to get are: Title, Size, Date posted, location, condition status, short description, link for the property and link to a thumbnail.
# I’ll give some examples below before we build the amazing for loop that will get us every result from every page.

# %%
location = first.find_all('p',class_='searchPropertyLocation')[0].text
location
# Out:
# '\r\n                    Póvoa de Santa Iria e Forte da Casa, Vila Franca de Xira, Lisboa\r\n                '

# %%
location[7:location.find(',')]
# Out:
# '               Póvoa de Santa Iria e Forte da Casa'

# %%
first.find_all('p')[7]
# Out:
# <p>73m²</p>

# %%
pd.to_datetime(first.find_all('div', class_='searchPropertyDate')[0]
# Out:
#   File "<ipython-input-40-ccdd953d3c91>", line 1
#     pd.to_datetime(first.find_all('div', class_='searchPropertyDate')[0]
#                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
first.find_all('p',cclass_='searchPropertyDescription')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-d7425f059cca> in <module>()
# ----> 1 first.find_all('p',cclass_='searchPropertyDescription')[0]
#
# IndexError: list index out of range

# %%
#gets all the links
for url in first.find_all('a'):
  print(url.get('href'))
# Out:
# /comprar-apartamento-t2-vila-franca-de-xira-povoa-de-santa-iria-e-forte-da-casa-tem-arrecadacao-c17a5cf3-88b9-11eb-9c85-060000000052.html
# /comprar-apartamento-t2-vila-franca-de-xira-povoa-de-santa-iria-e-forte-da-casa-tem-arrecadacao-c17a5cf3-88b9-11eb-9c85-060000000052.html
# /agencia/decisoes-e-solucoes-alverca/?cl=18447&sys=5
# /comprar-apartamento-t2-vila-franca-de-xira-povoa-de-santa-iria-e-forte-da-casa-tem-arrecadacao-c17a5cf3-88b9-11eb-9c85-060000000052.html
# /comprar-apartamento-t2-vila-franca-de-xira-povoa-de-santa-iria-e-forte-da-casa-tem-arrecadacao-c17a5cf3-88b9-11eb-9c85-060000000052.html

# %% [markdown]
# #Enough with tags, let’s scrape some pages already!
# Once your’re comfortable with the fields to extract and you found a way to extract them all from each result container, it’s time to setup the base of our crawler. The following lists will be created to handle our data and later be used to put together the dataframe.

# %%
# setting up the lists that will form our dataframe with all the results
titles = []
created = []
prices = []
areas = []
zone = []
condition = []
descriptions = []
urls = []
thumbnails = []

# %% [markdown]
# From a quick check on the original web page, I see there are 871 pages of results. We can give it a little more room and set the loop for 900 iterations. We’ll add something to break the loop if it finds a page without any house container. The page command is the &pn=x in the end of the address, where x is the results page number.
# The code is made up with two for loops, which navigate through every house in the page, for every page possible.
# If you follow along, you can notice we’re simply collecting the data we already explored above as we cycle through results. The price field turned out more complicated as there were cases containing both Sell and Rent prices separated by a “/”. In some results, the index 2 returned “Contacte Anunciante” so I had to update the code with an if statement to look for the price in the next index position.

# %%
# %%time

n_pages = 0

for page in range(0,2100):
    n_pages += 1
    sapo_url = 'https://casa.sapo.pt/Venda/Apartamentos/?sa=11&lp=10000&or=10'+'&pn='+str(page)
    r = get(sapo_url, headers=headers)
    page_html = BeautifulSoup(r.text, 'html.parser')
    house_containers = page_html.find_all('div', class_="searchResultProperty")
    if house_containers != []:
        for container in house_containers:
            
            # Price            
            price = container.find_all('span')[3].text
            if price == 'Contacte Anunciante':
                price = container.find_all('span')[3].text
                if price.find('/') != -1:
                    price = price[0:price.find('/')-1]
            if price.find('/') != -1:
                price = price[0:price.find('/')-1]
            
            price_ = [int(price[s]) for s in range(0,len(price)) if price[s].isdigit()]
            price = ''
            for x in price_:
                price = price+str(x)
            prices.append(int(price))

            # Zone
            location = container.find_all('p', class_="searchPropertyLocation")[0].text
            location = location[7:location.find(',')]
            zone.append(location)

            # Title
            name = container.find_all('span')[0].text
            titles.append(name)

            # Status
            status = container.find_all('p')[5].text
            condition.append(status)

            # Area
            m2 = container.find_all('p')[9].text
            if m2 != '-':
                m2 = m2.replace('\xa0','')
                m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                areas.append(m2)
                
            else:
                m2 = container.find_all('p')[7].text
                if m2 != '-':
                    m2 = m2.replace('\xa0','')
                    m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                    areas.append(m2)
                else:
                    areas.append(m2)

            # Creation date
            date = pd.to_datetime(container.find_all('div', class_="searchPropertyDate")[0].text[21:31])
            created.append(date)

            # Description
            desc = container.find_all('p', class_="searchPropertyDescription")[0].text[7:-6]
            descriptions.append(desc)

            # url
            link = 'https://casa.sapo.pt/' + container.find_all('a')[0].get('href')[1:-6]
            urls.append(link)

            # image
            img = str(container.find_all('img')[0])
            img = img[img.find('data-original_2x=')+18:img.find('id=')-2]
            thumbnails.append(img)
    else:
        break
    
    sleep(randint(1,2))
    
print('You scraped {} pages containing {} properties.'.format(n_pages, len(titles)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-b9c27869050d> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '\nn_pages = 0\n\nfor page in range(0,2100):\n    n_pages += 1\n    sapo_url = \'https://casa.sapo.pt/Venda/Apartamentos/?sa=11&lp=10000&or=10\'+\'&pn=\'+str(page)\n    r = get(sapo_url, headers=headers)\n    page_html = BeautifulSoup(r.text, \'html.parser\')\n    house_containers = page_html.find_all(\'div\', class_="searchResultProperty")\n    if house_containers != []:\n        for container in house_containers:\n            \n            # Price            \n            price = container.find_all(\'span\')[3].text\n            if price == \'Contacte Anunciante\':\n                price = container.find_all(\'span\')[3].text\n                if price.find(\'/\') != -1:\n                    price = price[0:price.find(\'/\')-1]\n            if price.find(\'/\') != -1:\n                price = price[0:price.find(\'/\')-1]\n            \n            price_ = [int(price[s]) for s in range(0,len(price)) if price[s].isdigit()]\n            price = \'\'\n            for x in price_:\n                price = price+str(x)\n            prices.append(int(price))\n\n            # Zone\n            location = container.find_all(\'p\', class_="searchPropertyLocation")[0].text\n            location = location[7:location.find(\',\')]\n            zone.append(location)\n\n            # Title\n            name = conta...
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# IndexError: list index out of range

# %%
cols = ['Title', 'Zone', 'Price', 'Size (m²)', 'Status', 'Description', 'Date', 'URL', 'Image']

lisboa = pd.DataFrame({'Title': titles,
                           'Price': prices,
                           'Size (m²)': areas,
                           'Zone': zone,
                           'Date': created,
                           'Status': condition,
                           'Description': descriptions,
                           'URL': urls,
                           'Image': thumbnails})[cols]

lisboa.to_excel('lisboa_raw.xls')

# lisboa = pd.read_excel('lisboa_raw.xls')
